# %% [markdown]
# <a href="https://colab.research.google.com/github/Minwoohh/DALC_Scala/blob/main/Colab_%EC%8B%A4%EC%8A%B5_%EC%9E%90%EB%A3%8C_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab 실습 하기
# # 1.마크다운으로 내 깃허브 링크 삽입하기
# http://github.com/Minwoohh/DALC_Scala

# %%
![](https://github.com/Minwoohh/DALC_Scala)

# %% [markdown]
# # 2.마크다운으로 이미지 삽입하기
# ![image.png](data:image/png;base64,...)

# %%
![](https://th.bing.com/th/id/OIP.X-vF4jhKrgV4bqBw1SYSkgHaHY?w=214&h=213&c=7&o=5&dpr=1.5&pid=1.7)

# %% [markdown]
# ## 3. 마크다운으로 수업 배운 것 정리해보기
# - 전공수업, 교양 수업, 오늘 ot내용, 요즘 준비하는 자격증 내용 등등 기타 자기가 최근 배운 것 아무거나 최소 3줄이상 작성해주세요. (이때 단어강조하기, 문장 띄어쓰기, 인용구등 사용하기)
#
# (중간에 사정이 생겨서 나갔는데 너무 불편했다. 실시간으로 물어볼 수 있는 것이 가장 좋은 것 같다. 후회했다. 어려웠지만 해결해서 정말 다행이였다. 따로 공부하는 시간을 가지고 용어를 정리할 필요가 있을 것 같다.)

# %%
1.
